# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data/worldcities.csv')

# %%
df = df.loc[df['population'] >= 100000]

# %%
df
# Out:
#               city   city_ascii      lat       lng    country iso2 iso3  \
# 0            Tokyo        Tokyo  35.6897  139.6922      Japan   JP  JPN
# 1          Jakarta      Jakarta  -6.1750  106.8275  Indonesia   ID  IDN
# 2            Delhi        Delhi  28.6100   77.2300      India   IN  IND
# 3        Guangzhou    Guangzhou  23.1300  113.2600      China   CN  CHN
# 4           Mumbai       Mumbai  19.0761   72.8775      India   IN  IND
# ...            ...          ...      ...       ...        ...  ...  ...
# 11857  Dzolokpuita  Dzolokpuita   6.7862    0.4437      Ghana   GH  GHA
# 11861    Ad Dujayl    Ad Dujayl  33.8389   44.2481       Iraq   IQ  IRQ
# 11863       Gwelej       Gwelej  14.7500   36.7167    Eritrea   ER  ERI
# 11864       Babīlē       Babile   9.2167   42.3333   Ethiopia   ET  ETH
# 11865  Ra’s Ghārib  Ra's Gharib  28.3597   33.0775      Egypt   EG  EGY
#
#              admin_name  capital  population          id
# ...
